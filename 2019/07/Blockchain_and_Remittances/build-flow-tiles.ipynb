# %%
import csv, glob, json, math, os, re

def process_row(row):
    year, org, dst, val = row                
    org_wm = centroids_by_iso_alpha_3[org]['epsg_3857']
    dst_wm = centroids_by_iso_alpha_3[dst]['epsg_3857']
    mid_wm = [((dst_wm[0] + org_wm[0]) / 2), ((dst_wm[1] + org_wm[1]) / 2)]  
    mid_offset = [0,0]                
    dist = math.sqrt(math.pow(dst_wm[0] - org_wm[0],2) +  math.pow(dst_wm[1] - org_wm[1],2))
    if abs(dst_wm[1] - org_wm[1]) > abs(dst_wm[0] - org_wm[0]):
        if dst_wm[1] > org_wm[1]:
            mid_offset[0] = 1
            mid_wm[0] += dist*0.5
        else:
            mid_offset[0] = -1
            mid_wm[0] -= dist*0.5
    else:
        if dst_wm[0] < org_wm[0]:
            mid_offset[1] = 1   
            mid_wm[1] += dist*0.5
        else: 
            mid_offset[1] = -1
            mid_wm[1] -= dist*0.5
    return {"year": year, 
            "org": org.lower(),
            "org_wm": org_wm,
            "dst_wm": dst_wm,
            "dst": dst.lower(),
            "mid_wm": mid_wm,
            "mid_offset": mid_offset,
            "export_val": val
            }

def to_json(col, fname):
    with open(fname, "w") as f:
        json.dump(col, f)
        
def hex2rgb(h):
    return tuple(int(h.strip("#")[i:i+2], 16) for i in (0, 2 ,4))

def get_header_and_lines(fname):
    lines = []
    with open(fname) as f:
        for l in f.readlines():
            lines.append(l)
    return lines[5], lines[6:-1]

def find_name(name, features):
    match = False
    for f in features:
        if name in f["properties"]["names"]:
            match = True
            break
    if match:
        return f["properties"]["iso_alpha-3"]
    else:
        return None

# %%
# if not os.path.exists("../data/DealsAndTIVs"):
#     os.makedirs("../data/DealsAndTIVs")

# %%
# fnames = glob.glob("../data/DealsAndTIVs-*-*")
# fnames

# %%
# o_f = "../data/DealsAndTIVs/DealsAndTIVs-1980-2018.csv"
# lines = []
# headers = []
# for f in fnames:
#     header, line = get_header_and_lines(f)
#     headers.append(header)
#     lines += line
# print (len(lines), len(headers))
# lines = list(set(lines))
# headers = list(set(headers))
# print (len(lines), len(headers))

# with open(o_f,"w") as f:
#     f.write(headers[0])
#     for l in lines:
#         f.write(l)

# %%
raw_data = []
with open("bilateral_remittances_2010-2017_long_format_v3.csv") as f:
    reader = csv.DictReader(f,delimiter=",")
    for row in reader:
        raw_data.append(row)

# %%
raw_data
# Out:
# [{'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '30019.18703'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '28125.88643'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '25675.38559'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2014',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '23997.66319'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '23174.28516'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2012',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '22811.25'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '22587.28492'},
#  {'Armament category': '',
#   'Buyer': 'Mexico',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '21693.41602'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '17337.69141'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2012',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '17021.32617'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '16233.90194'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '16140.76671'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2014',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15848.82522'},
#  {'Armament category': '',
#   'Buyer': 'India',
#   'Deal ID': '',
#   'Delivery year': '2012',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United Arab Emirates',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15684.81445'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15561.79844'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15547.56218'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15417.95558'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2014',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15194.70241'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '15145.43358'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '14851.31576'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '14680.21191'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Hong Kong',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values':

#   'Deal ID': '',
#   'Delivery year': '2014',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
# ...
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '922.0632076'},
#  {'Armament category': '',
#   'Buyer': 'Philippines',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Kuwait',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '921.6372078'},
#  {'Armament category': '',
#   'Buyer': 'Belgium',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Italy',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '921.1766766'},
#  {'Armament category': '',
#   'Buyer': 'Hungary',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Germany',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '920.7513046'},
#  {'Armament category': '',
#   'Buyer': 'Nigeria',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Cameroon',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '916.0613403'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Germany',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '915.4085693'},
#  {'Armament category': '',
#   'Buyer': 'Belgium',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Italy',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '914.8612635'},
#  {'Armament category': '',
#   'Buyer': 'Peru',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '914.2567132'},
#  {'Armament category': '',
#   'Buyer': 'Viet Nam',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Canada',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '912.8907784'},
#  {'Armament category': '',
#   'Buyer': 'Egypt',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '912.8071122'},
#  {'Armament category': '',
#   'Buyer': 'Lebanon',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Australia',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '911.1214224'},
#  {'Armament category': '',
#   'Buyer': 'Philippines',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Qatar',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '910.3556519'},
#  {'Armament category': '',
#   'Buyer': 'Nigeria',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Spain',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '909.3237915'},
#  {'Armament category': '',
#   'Buyer': 'Peru',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '906.9605505'},
#  {'Armament category': '',
#   'Buyer': 'Ecuador',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Spain',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '904.5431451'},
#  {'Armament category': '',
#   'Buyer': 'Germany',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'France',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '902.6972639'},
#  {'Armament category': '',
#   'Buyer': 'France',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Canada',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '902.1577759'},
#  {'Armament category': '',
#   'Buyer': 'Italy',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'France',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '901.0776367'},
#  {'Armament category': '',
#   'Buyer': 'Malaysia',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Singapore',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '900.757498'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2012',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Germany',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '898.704895'},
#  {'Armament category': '',
#   'Buyer': 'Jordan',
#   'Deal ID': '',
#   'Delivery year': '2011',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Saudi Arabia',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '898.1863403'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United Kingdom',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '896.0390595'},
#  {'Armament category': '',
#   'Buyer': 'Poland',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '895.3250059'},
#  {'Armament category': '',
#   'Buyer': 'Poland',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '895.225368'},
#  {'Armament category': '',
#   'Buyer': 'Georgia',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Russia',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '892.983958'},
#  {'Armament category': '',
#   'Buyer': 'Germany',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Spain',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '892.4346446'},
#  {'Armament category': '',
#   'Buyer': 'Lebanon',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Australia',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '889.7768435'},
#  {'Armament category': '',
#   'Buyer': 'Italy',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Switzerland',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '889.7443145'},
#  {'Armament category': '',
#   'Buyer': 'Azerbaijan',
#   'Deal ID': '',
#   'Delivery year': '2010',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Russia',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '889.7076416'},
#  {'Armament category': '',
#   'Buyer': 'Egypt',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Qatar',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '888.6613891'},
#  {'Armament category': '',
#   'Buyer': 'Spain',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '888.4534356'},
#  {'Armament category': '',
#   'Buyer': 'India',
#   'Deal ID': '',
#   'Delivery year': '2015',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Singapore',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '888.3140779'},
#  {'Armament category': '',
#   'Buyer': 'China',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Bangladesh',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '888.2415972'},
#  {'Armament category': '',
#   'Buyer': 'Spain',
#   'Deal ID': '',
#   'Delivery year': '2016',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '886.599238'},
#  {'Armament category': '',
#   'Buyer': 'India',
#   'Deal ID': '',
#   'Delivery year': '2017',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'Singapore',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '886.2785978'},
#  {'Armament category': '',
#   'Buyer': 'Peru',
#   'Deal ID': '',
#   'Delivery year': '2014',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '885.7362964'},
#  {'Armament category': '',
#   'Buyer': 'Bermuda',
#   'Deal ID': '',
#   'Delivery year': '2013',
#   'Delivery year is estimate': '',
#   'Description': '',
#   'Designation': '',
#   'Local production': '',
#   'Numbers delivered': '',
#   'Numbers delivered is estimate': '',
#   'Order date': '',
#   'Order date is estimate': '',
#   'SIPRI estimate': '',
#   'Seller': 'United States',
#   'Status': '',
#   'TIV deal unit': '',
#   'TIV delivery values': '884.8198986'},
#  ...]

# %%
# Standardize names
names = []
for row in raw_data:
    org = row['Seller']
    dst = row['Buyer']
    if org not in names:
        names.append(org)
    if dst not in names:
        names.append(dst)

# %%
with open("country-centroids.geojson") as f:
    centroids = json.load(f)

# %%
with open("centroids_by_iso_alpha_3.json") as f:
    centroids_by_iso_alpha_3 = json.load(f)

# %%
names_to_iso = {}
for n in names:
    iso = find_name(n, centroids["features"])
    if iso is None:
        m = re.search(r"\((.+)\)", n)
        if m is None:
                if n == "Syria rebels*":
                    alt_n = "Syria"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso

                elif n == "Libya HoR":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Ukraine Rebels*":
                    alt_n = "Ukraine"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Lebanon Palestinian rebels*":
                    alt_n = "Lebanon"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Libya GNC":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                else:
                    print ("No match for %s" % n)
        else:
            alt_n = m.group(0).replace("(","").replace(")","").split("/")[0]
            iso = find_name(alt_n, centroids["features"])
            if iso is not None:
                names_to_iso[n] = iso
    else:
        names_to_iso[n] = iso

# %%
# Get all years
years = []
for row in raw_data:
    if row['Delivery year'] not in years and row['Delivery year'] != 'Yes' and row['Delivery year'] != 'No':
        years.append(row['Delivery year'])
years.sort()
years
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
collection = {}
for y in years:
    collection[y] = {}
    
for row in raw_data:
    year = row['Delivery year']
    org = row["Seller"]
    dst = row["Buyer"]
    if year in years and org in names_to_iso and dst in names_to_iso:
        o = names_to_iso[org]
        d = names_to_iso[dst]
        if o not in collection[year]: 
            collection[year][o] = {}
        if d not in collection[year][o]:
            collection[year][o][d] = 0
        collection[year][o][d] += float(row['TIV delivery values'])

# %%
out_dir = "../data/sipri_arms_transfers_db/tiv/"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
for year in years:
    col = []
    fname = os.path.join(out_dir, str(year) + ".json")
    for org in collection[year]:
        for dst in collection[year][org]:
            val = collection[year][org][dst]
            col.append(process_row([year,org,dst,val]))
    to_json(col, fname)

# %%
#!rsync -rcav ../data/sipri_arms_transfers_db USERNAME@HOSTNAME:/FILE_PATH
