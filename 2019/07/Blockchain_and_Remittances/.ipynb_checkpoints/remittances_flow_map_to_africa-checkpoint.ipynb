# %%
import csv, glob, json, math, os, re

def process_row(row):
    year, org, dst, val = row                
    org_wm = centroids_by_iso_alpha_3[org]['epsg_3857']
    dst_wm = centroids_by_iso_alpha_3[dst]['epsg_3857']
    mid_wm = [((dst_wm[0] + org_wm[0]) / 2), ((dst_wm[1] + org_wm[1]) / 2)]  
    mid_offset = [0,0]                
    dist = math.sqrt(math.pow(dst_wm[0] - org_wm[0],2) +  math.pow(dst_wm[1] - org_wm[1],2))
    if abs(dst_wm[1] - org_wm[1]) > abs(dst_wm[0] - org_wm[0]):
        if dst_wm[1] > org_wm[1]:
            mid_offset[0] = 1
            mid_wm[0] += dist*0.5
        else:
            mid_offset[0] = -1
            mid_wm[0] -= dist*0.5
    else:
        if dst_wm[0] < org_wm[0]:
            mid_offset[1] = 1   
            mid_wm[1] += dist*0.5
        else: 
            mid_offset[1] = -1
            mid_wm[1] -= dist*0.5
    return {"year": year, 
            "org": org.lower(),
            "org_wm": org_wm,
            "dst_wm": dst_wm,
            "dst": dst.lower(),
            "mid_wm": mid_wm,
            "mid_offset": mid_offset,
            "export_val": val
            }

def to_json(col, fname):
    with open(fname, "w") as f:
        json.dump(col, f)
        
def hex2rgb(h):
    return tuple(int(h.strip("#")[i:i+2], 16) for i in (0, 2 ,4))

def get_header_and_lines(fname):
    lines = []
    with open(fname) as f:
        for l in f.readlines():
            lines.append(l)
    return lines[5], lines[6:-1]

def find_name(name, features):
    match = False
    for f in features:
        if name in f["properties"]["names"]:
            match = True
            break
    if match:
        return f["properties"]["iso_alpha-3"]
    else:
        return None

# %%
raw_data = []
with open("remittances_to_africa.csv") as f:
    reader = csv.DictReader(f,delimiter=",")
    for row in reader:
        raw_data.append(row)

# %%
raw_data
# Out:
# [{'Remittance Amount (millions of USD)': '3.824752339',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '4.050828429',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '4.056796317',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '4.42837806',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '4.664853448',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.27814424',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '1.38320291',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '1.4664464',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '1.68625448',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.779434856',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.780144737',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.931237818',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '2.034365918',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AND',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '654.7861328',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '698.6681519',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '740.7151489',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '3249.350639',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '3495.69058',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '3549.98145',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '3900.236228',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '4108.508842',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '12.99848156',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '13.81885858',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '13.85446373',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '15.47964872',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '16.30626196',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '2.343594313',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '2.536229134',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '2.68886352',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '5.604910141',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '5.963593441',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '5.980371548',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '6.577221336',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '6.928444955',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ASM',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '755.2563477',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '813.2213745',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '862.1623535',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '815.4720014',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '862.8608084',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '871.2657315',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '951.5467586',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1002.359356',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUS',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '59.73310471',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '64.24090576',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '68.10703278',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '58.39117372',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '62.04077929',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '62.77850011',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '68.89006988',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '72.56879961',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'AUT',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '41.57082748',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '44.33254623',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '47.00055313',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '27.6542227',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '29.64166213',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '29.81792727',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '32.66929806',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '34.41383858',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.135618939',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'BGR',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.145109524',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': '

#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '10001.62598',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '10603.54102',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '9081.368885',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '9653.121176',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '9654.337736',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '10536.49158',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '11099.14024',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'USA',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.320436716',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.345319569',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.36610147',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.478869532',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.505831614',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.507137623',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.55705928',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.586806246',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VEN',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.945820501',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VNM',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.015914348',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VNM',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.02159871',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VNM',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.141482595',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VNM',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.202437766',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VNM',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.136042675',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VUT',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.146124666',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VUT',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.14694228',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VUT',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.164185853',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VUT',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.172953377',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'VUT',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '5.101952357',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ZAF',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '5.458371894',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ZAF',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '5.474497996',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ZAF',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '6.034588096',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ZAF',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '6.356835101',
#   'Remittance-Receiving Country': 'PHL',
#   'Remittance-Sending Country': 'ZAF',
#   'Year': '2017'}]

# %%
# Standardize names
names = []
for row in raw_data:
    org = row['Remittance-Sending Country']
    dst = row['Remittance-Receiving Country']
    if org not in names:
        names.append(org)
    if dst not in names:
        names.append(dst)

# %%
with open("country-centroids.geojson") as f:
    centroids = json.load(f)

# %%
with open("centroids_by_iso_alpha_3.json") as f:
    centroids_by_iso_alpha_3 = json.load(f)

# %%
names_to_iso = {}
for n in names:
    iso = find_name(n, centroids["features"])
    if iso is None:
        m = re.search(r"\((.+)\)", n)
        if m is None:
                if n == "Syria rebels*":
                    alt_n = "Syria"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso

                elif n == "Libya HoR":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Ukraine Rebels*":
                    alt_n = "Ukraine"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Lebanon Palestinian rebels*":
                    alt_n = "Lebanon"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Libya GNC":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                else:
                    print ("No match for %s" % n)
        else:
            alt_n = m.group(0).replace("(","").replace(")","").split("/")[0]
            iso = find_name(alt_n, centroids["features"])
            if iso is not None:
                names_to_iso[n] = iso
    else:
        names_to_iso[n] = iso

# %%
# Get all years
years = []
for row in raw_data:
    if row['Year'] not in years: #and row['Year'] != 'Yes' and row['Year'] != 'No':
        years.append(row['Year'])
years.sort()
years
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
collection = {}
for y in years:
    collection[y] = {}
    
for row in raw_data:
    year = row['Year']
    org = row["Remittance-Sending Country"]
    dst = row["Remittance-Receiving Country"]
    if year in years and org in names_to_iso and dst in names_to_iso:
        o = names_to_iso[org]
        d = names_to_iso[dst]
        if o not in collection[year]: 
            collection[year][o] = {}
        if d not in collection[year][o]:
            collection[year][o][d] = 0
        collection[year][o][d] += float(row['Remittance Amount (millions of USD)'])

# %%
#collection

# %%
out_dir = "../Blockchain_and_Remittances/top_receivers/africa/"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
for year in years:
    col = []
    fname = os.path.join(out_dir, str(year) + ".json")
    for org in collection[year]:
        for dst in collection[year][org]:
            val = collection[year][org][dst]
            col.append(process_row([year,org,dst,val]))
    to_json(col, fname)

# %%
fname
# Out:
# '../Blockchain_and_Remittances/remittances_flow_json_data_years/2017.json'

# %%
#!rsync -rcav ../data/sipri_arms_transfers_db USERNAME@HOSTNAME:/FILE_PATH
