# %%
import csv, glob, json, math, os, re

def process_row(row):
    year, org, dst, val = row                
    org_wm = centroids_by_iso_alpha_3[org]['epsg_3857']
    dst_wm = centroids_by_iso_alpha_3[dst]['epsg_3857']
    mid_wm = [((dst_wm[0] + org_wm[0]) / 2), ((dst_wm[1] + org_wm[1]) / 2)]  
    mid_offset = [0,0]                
    dist = math.sqrt(math.pow(dst_wm[0] - org_wm[0],2) +  math.pow(dst_wm[1] - org_wm[1],2))
    if abs(dst_wm[1] - org_wm[1]) > abs(dst_wm[0] - org_wm[0]):
        if dst_wm[1] > org_wm[1]:
            mid_offset[0] = 1
            mid_wm[0] += dist*0.5
        else:
            mid_offset[0] = -1
            mid_wm[0] -= dist*0.5
    else:
        if dst_wm[0] < org_wm[0]:
            mid_offset[1] = 1   
            mid_wm[1] += dist*0.5
        else: 
            mid_offset[1] = -1
            mid_wm[1] -= dist*0.5
    return {"year": year, 
            "org": org.lower(),
            "org_wm": org_wm,
            "dst_wm": dst_wm,
            "dst": dst.lower(),
            "mid_wm": mid_wm,
            "mid_offset": mid_offset,
            "export_val": val
            }

def to_json(col, fname):
    with open(fname, "w") as f:
        json.dump(col, f)
        
def hex2rgb(h):
    return tuple(int(h.strip("#")[i:i+2], 16) for i in (0, 2 ,4))

def get_header_and_lines(fname):
    lines = []
    with open(fname) as f:
        for l in f.readlines():
            lines.append(l)
    return lines[5], lines[6:-1]

def find_name(name, features):
    match = False
    for f in features:
        if name in f["properties"]["names"]:
            match = True
            break
    if match:
        return f["properties"]["iso_alpha-3"]
    else:
        return None

# %%
raw_data = []
with open("remittances_to_sub-saharan_africa.csv") as f:
    reader = csv.DictReader(f,delimiter=",")
    for row in reader:
        raw_data.append(row)

# %%
raw_data
# Out:
# [{'Remittance Amount (millions of USD)': '0.003015361',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.002624326',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000529145',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.008649334',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001839653',
#   'Remittance-Receiving Country': 'LSO',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.002020506',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001792701',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.077498135',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001259435',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.07790302',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.083383163',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.028292694',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000331588',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.003019625',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.002982691',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.002591165',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000523657',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.009132103',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001576989',
#   'Remittance-Receiving Country': 'LSO',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001952085',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001725994',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.077111724',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001221017',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.077352097',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.079574376',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.026459172',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000307524',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.003208424',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.002967022',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.002558902',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.009187463',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.009827339',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.001453561',
#   'Remittance-Receiving Country': 'LSO',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.002650074',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.001773813',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.076891663',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.001188239',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.07535214',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.07334737',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.023817259',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.002006225',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.003393902',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.003612353',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002862592',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.009502392',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.010779535',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.001347647',
#   'Remittance-Receiving Country': 'LSO',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002118227',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002766385',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.076566463',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.001737746',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.0755022',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.073844471',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.021658219',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002072677',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.003697064',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.003814756',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.00297692',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.009910995',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.012208988',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001627079',
#   'Remittance-Receiving Country': 'LSO',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.002317357',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.003070742',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.080607234',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001891993',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.08246654',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.077289841',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.02574855',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.002192584',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.003715278',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ABW',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '6.742292404',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.059109036',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '1.548917055',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.085647807',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '9.152219772',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.076574005',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '1.692148209',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.090711899',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '9.085158348',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.073117249',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '1.597259522',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.089244254',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.071531289',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.060917613',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.065603462',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.603791738',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '6.102662159',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.057822161',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '6.673735806',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '4.320604559',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.071342433',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.033150165',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.065567693',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.595784064',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '5.74288186',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.063303322',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '7.166540988',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '4.716320368',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.07140164',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.054880634',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.049707737',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.558185643',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '5.169462865',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.062983475',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '7.562788115',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '3.2545528',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.047944879',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.024839254',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.012924169',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.562439492',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '4.710620876',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.040366395',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '8.024437832',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '2.865629863',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.050749244',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.013548684',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.247749041',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.588681302',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '5.600259897',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.044262473',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '8.063971519',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '3.00052079',
#   'Remittance-Receiving Country': 'STP',
#   'Remittance-Sending Country': 'AGO',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '13.00487491',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '149.6621924',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '13.32174232',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '152.3829853',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '13.70730205',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '151.333762',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '17.05343781',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '155.3127892',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '18.00895473',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '169.638862',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ARE',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '7.17E-06',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001146383',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.00315834',
#   'Remittance-Receiving Country': 'BWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001901602',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000511208',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.031727898',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.017397155',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.004114225',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.014963716',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.00751515',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.002906239',
#   'Remittance-Receiving Country': 'GNB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.063160051',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.054079471',
#   'Remittance-Receiving Country': 'LBR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.015148474',
#   'Remittance-Receiving Country': 'MDG',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000490848',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.011182804',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001363296',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.006117293',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000515777',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.149205379',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.010893379',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.347804744',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.005447756',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.444290199',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.002620265',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.004094997',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.033861304',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.000248172',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.0619485',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.001747596',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001132407',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.003646546',
#   'Remittance-Receiving Country': 'BWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.00182352',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000485774',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.031571624',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.017395583',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.004051674',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.014836721',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.007382543',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.002812142',
#   'Remittance-Receiving Country': 'GNB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.068432006',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.064422628',
#   'Remittance-Receiving Country': 'LBR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.014817827',
#   'Remittance-Receiving Country': 'MDG',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000475276',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.010851136',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001367156',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.003206373',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000513185',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.145226525',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.010468523',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.329465268',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.00535462',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.416093044',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.00252583',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.004082478',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.036426737',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.000262011',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.06590046',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.001744791',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.001631666',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.00266061',
#   'Remittance-Receiving Country': 'BWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.006123493',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.000487334',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.031411573',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.017304202',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.004001225',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.259937461',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.007398939',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.003918669',
#   'Remittance-Receiving Country': 'GNB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.073769669',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.089294678',
#   'Remittance-Receiving Country': 'LBR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.014750914',
#   'Remittance-Receiving Country': 'MDG',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.000645923',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.011042457',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.00136192',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.005344873',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.000389467',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.140770814',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.009713062',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.323182895',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.004957332',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.374546715',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.016464448',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.005061235',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.037088484',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.000261955',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.069610005',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.001788102',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.001279121',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002548531',
#   'Remittance-Receiving Country': 'BWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.048066289',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.000533145',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.031992022',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.02241686',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.004716409',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.27828558',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.005436707',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.005888393',
#   'Remittance-Receiving Country': 'GNB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.084263483',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.093980357',
#   'Remittance-Receiving Country': 'LBR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.008884425',
#   'Remittance-Receiving Country': 'MDG',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.000565148',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.018562465',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.001380343',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.002648016',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.000101808',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.2198988',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.010381937',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.734810511',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.004209189',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.345818987',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.017811344',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.004760454',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.036906312',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.000176552',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.077542148',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.000680337',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001644976',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001797558',
#   'Remittance-Receiving Country': 'BWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.052643585',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.000350053',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.036806005',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.023672893',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.004904777',
#   'Remittance-Receiving Country': 'GMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.29025186',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.005754708',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.006537296',
#   'Remittance-Receiving Country': 'GNB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.095437506',
#   'Remittance-Receiving Country': 'KEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.09936586',
#   'Remittance-Receiving Country': 'LBR',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.009284756',
#   'Remittance-Receiving Country': 'MDG',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.000618276',
#   'Remittance-Receiving Country': 'MWI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.020604701',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.00145319',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001444372',
#   'Remittance-Receiving Country': 'MOZ',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.001951605',
#   'Remittance-Receiving Country': 'NAM',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.239417674',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.010866328',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.925722672',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.004303921',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.411129712',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.018841756',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.005450375',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.049956999',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.000193593',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.077924172',
#   'Remittance-Receiving Country': 'CPV',
#   'Remittance-Sending Country': 'ARG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.035237875',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.004113819',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.61826015',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.126819074',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.050257649',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.00445775',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.6286599',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.136186898',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.051330868',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.004454827',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.62711847',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.125242561',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.828038094',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.004864434',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.74541292',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.051285143',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.843425698',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.004882872',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.748321872',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.048316188',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.843197683',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.085847036',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.73090486',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.043554344',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.045187474',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.089602136',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.73578183',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.039724972',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.103750113',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.093455028',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.80365044',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.047227355',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'ATG',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.021083131',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'AUS',
# ...
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.358401269',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '4.877346516',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.029780686',
#   'Remittance-Receiving Country': 'SWZ',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.1714883',
#   'Remittance-Receiving Country': 'TZA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '2.540236712',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '1.060385704',
#   'Remittance-Receiving Country': 'UGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.125048384',
#   'Remittance-Receiving Country': 'ZMB',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.000413076',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.78844744',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.083148682',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '12.3895749',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.988002173',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.169448777',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '2.165040189',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '2.122070161',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '2.071303056',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '100.3604387',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '4.716681097',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '10.09396695',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.459398577',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.892210967',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '5.267670562',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.101591972',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.798859211',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.075719697',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '12.46013135',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.005910721',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.182152251',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '2.211032896',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '2.126510848',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '2.082625782',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '101.4045765',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '4.639756323',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '10.21275784',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.46278111',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.786609908',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '5.358075448',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.102027214',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.147355841',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.09882526',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '12.51010975',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.013225015',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '20.93465061',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '2.249134177',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '2.127472463',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '2.059967789',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '99.4250018',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '4.313421864',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '10.26680206',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.435931248',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '1.614651062',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '6.74617354',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2015'},
#  {'Remittance Amount (millions of USD)': '0.105293692',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.868643826',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.156407723',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '12.32481227',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.248877001',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '21.87927938',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.586052525',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '2.121822133',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '3.078321145',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '100.7936624',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '4.394652239',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '13.01639335',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.376766673',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '1.477971256',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '6.100218444',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2016'},
#  {'Remittance Amount (millions of USD)': '0.040062166',
#   'Remittance-Receiving Country': 'AGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.117093641',
#   'Remittance-Receiving Country': 'BEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.759274293',
#   'Remittance-Receiving Country': 'BDI',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '14.179382',
#   'Remittance-Receiving Country': 'CMR',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.318852517',
#   'Remittance-Receiving Country': 'ETH',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '22.82008839',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.678823007',
#   'Remittance-Receiving Country': 'GIN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '2.23380062',
#   'Remittance-Receiving Country': 'MUS',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '3.351562115',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '110.0908836',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '4.599694081',
#   'Remittance-Receiving Country': 'RWA',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '14.44881941',
#   'Remittance-Receiving Country': 'SEN',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.38524625',
#   'Remittance-Receiving Country': 'SLE',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '1.757098134',
#   'Remittance-Receiving Country': 'ZAF',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '6.984308074',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEL',
#   'Year': '2017'},
#  {'Remittance Amount (millions of USD)': '0.861923873',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '24.67426491',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '549.5900879',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '32.84259415',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2010'},
#  {'Remittance Amount (millions of USD)': '0.870573282',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '24.61336708',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '581.6378174',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '32.93055344',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2011'},
#  {'Remittance Amount (millions of USD)': '0.812870383',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '22.42691422',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '580.2116699',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '31.37647247',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2012'},
#  {'Remittance Amount (millions of USD)': '0.616820942',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '1.116471205',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.937071091',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '30.69178352',
#   'Remittance-Receiving Country': 'NER',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '611.5425145',
#   'Remittance-Receiving Country': 'NGA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '23.49690313',
#   'Remittance-Receiving Country': 'TGO',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2013'},
#  {'Remittance Amount (millions of USD)': '0.60676267',
#   'Remittance-Receiving Country': 'BFA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '1.113635327',
#   'Remittance-Receiving Country': 'GHA',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2014'},
#  {'Remittance Amount (millions of USD)': '0.936217246',
#   'Remittance-Receiving Country': 'MLI',
#   'Remittance-Sending Country': 'BEN',
#   'Year': '2014'},
#  ...]

# %%
# Standardize names
names = []
for row in raw_data:
    org = row['Remittance-Sending Country']
    dst = row['Remittance-Receiving Country']
    if org not in names:
        names.append(org)
    if dst not in names:
        names.append(dst)

# %%
with open("country-centroids.geojson") as f:
    centroids = json.load(f)

# %%
with open("centroids_by_iso_alpha_3.json") as f:
    centroids_by_iso_alpha_3 = json.load(f)

# %%
names_to_iso = {}
for n in names:
    iso = find_name(n, centroids["features"])
    if iso is None:
        m = re.search(r"\((.+)\)", n)
        if m is None:
                if n == "Syria rebels*":
                    alt_n = "Syria"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso

                elif n == "Libya HoR":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Ukraine Rebels*":
                    alt_n = "Ukraine"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Lebanon Palestinian rebels*":
                    alt_n = "Lebanon"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                elif n == "Libya GNC":
                    alt_n = "Libya"
                    iso = find_name(alt_n, centroids["features"])
                    names_to_iso[n] = iso
                else:
                    print ("No match for %s" % n)
        else:
            alt_n = m.group(0).replace("(","").replace(")","").split("/")[0]
            iso = find_name(alt_n, centroids["features"])
            if iso is not None:
                names_to_iso[n] = iso
    else:
        names_to_iso[n] = iso

# %%
# Get all years
years = []
for row in raw_data:
    if row['Year'] not in years: #and row['Year'] != 'Yes' and row['Year'] != 'No':
        years.append(row['Year'])
years.sort()
years
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
collection = {}
for y in years:
    collection[y] = {}
    
for row in raw_data:
    year = row['Year']
    org = row["Remittance-Sending Country"]
    dst = row["Remittance-Receiving Country"]
    if year in years and org in names_to_iso and dst in names_to_iso:
        o = names_to_iso[org]
        d = names_to_iso[dst]
        if o not in collection[year]: 
            collection[year][o] = {}
        if d not in collection[year][o]:
            collection[year][o][d] = 0
        collection[year][o][d] += float(row['Remittance Amount (millions of USD)'])

# %%
#collection

# %%
out_dir = "../Blockchain_and_Remittances/top_receivers/ssafrica/"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
for year in years:
    col = []
    fname = os.path.join(out_dir, str(year) + ".json")
    for org in collection[year]:
        for dst in collection[year][org]:
            val = collection[year][org][dst]
            col.append(process_row([year,org,dst,val]))
    to_json(col, fname)

# %%
fname
# Out:
# '../Blockchain_and_Remittances/top_receivers/africa/2017.json'

# %%
#!rsync -rcav ../data/sipri_arms_transfers_db USERNAME@HOSTNAME:/FILE_PATH
